# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl

from warnings import filterwarnings
filterwarnings("ignore")

# %%
df = pd.read_csv("../../media/data/art/cksum.csv", error_bad_lines=False, header=None, usecols=[0,1])
df["value"] = df[1].apply(lambda x: x.split()[1]).apply(lambda x: int(x,16))
df = df.sample(len(df.index))
df.head()
# Out:
#                                                         0  \
# 234972      delton.59830 > whatsapp-chatd-edge-shv-01-...
# 243212      104.244.42.130.https > delton.55882: Flags...
# 47410       mba01s08-in-f5.1e100.net.https > delton.34...
# 206607      62.8.89.161.wananchi.com.https > delton.44...
# 27706       delton.39204 > bru30r3.msedge.net.https: F...
#
#                               1  value
# 234972   cksum 0x6949 (correct)  26953
# 243212   cksum 0x737b (correct)  29563
# 47410    cksum 0xff5a (correct)  65370
# 206607   cksum 0xa446 (correct)  42054
# 27706    cksum 0x0c45 (correct)   3141

# %%
x = df.loc[0,1].split()[1]

# %%
x.encode("utf-8")
# Out:
# b'0x021b'

# %%
int(x,16)
# Out:
# 539

# %%
int(0x021b)
# Out:
# 539

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 293776 entries, 234972 to 96891
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       293776 non-null  object
#  1   1       293776 non-null  object
#  2   value   293776 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 9.0+ MB

# %%
df.loc[350,0]
# Out:
# '    delton.33558 > 162.159.153.4.https: Flags [.]'

# %%
np.random.rand(5)
# Out:
# array([0.30459611, 0.2020471 , 0.41931342, 0.0051953 , 0.76311757])

# %%
df["x"] = np.random.rand(len(df.index)) * 100000 * np.random.rand(len(df.index))
df["y"] = np.random.rand(len(df.index)) * 100000

# %%
plt.rcParams.update(mpl.rcParamsDefault)
plt.figure(figsize=(10,5))

for i in list(df["value"].unique()):
    marker = np.random.choice([".",",","o","v","^","<",">","1","2","3","4","8","s","p","P",
                               "*","h","H","+","x","X","d","D","|","_"])

plt.xticks([])
plt.yticks([])

plt.xlim(1000,80000)
plt.ylim(1000,80000)
    
plt.scatter(df["x"], df["y"], marker=marker, c=df["value"], s=df["y"]/1e3, alpha=0.5)
plt.show();

# %%
dfs = df.sample(1000)

style = np.random.choice(["dark_background"])#, "fivethirtyeight", "ggplot"])
plt.style.use(style)
plt.figure(figsize=(15,10))

plt.xticks([])
plt.yticks([])

plt.xlim(10000,20000)
plt.ylim(10000,20000)

for i in range(4):
    marker = np.random.choice(["o","*","D"])#,",","^","<",">","1","2","3","4",".","s","p","P",
#                                "v","h","H","+","x","X","d","8","|","_"])
    plt.scatter(dfs["x"], dfs["y"], marker=marker, c=dfs["value"], s=dfs["value"]/10, alpha=0.5)

plt.show();

# %%
df = pd.read_csv("../../media/data/art/cksum.csv", error_bad_lines=False, header=None, usecols=[0,1])
df["value"] = df[1].apply(lambda x: x.split()[1]).apply(lambda x: int(x,16))
df = df.sample(len(df.index))

# %%
df["x"] = np.random.rand(len(df.index)) * 100000 * np.random.rand(len(df.index))
df["y"] = np.random.rand(len(df.index)) * 100000

dfs = df.sample(20000)

style = np.random.choice(["dark_background"])
plt.style.use(style)
plt.figure(figsize=(15,10))

plt.xticks([])
plt.yticks([])

plt.xlim(6000,60000)
plt.ylim(6000,60000)

for i in dfs.index:
    marker = np.random.choice([".",",","o","v","^","<",">","1","2","3","4","8","s","p","P",
                               "*","h","H","+","x","X","d","D","|","_"])
    r, g, b, a = 
    c = ((0,1,1,0))
    
    rand_divisor = np.random.choice(np.random.randint(1,501,len(df.index)))
    size = dfs.loc[i,"value"]/(np.random.choice(np.abs(rand_divisor/np.random.normal(-1,1,len(df.index)))))

    alpha = np.random.choice(np.abs(np.random.normal(0,1,len(df.index))))
    if alpha > 1:
        alpha = alpha - np.floor(alpha)

    plt.scatter(dfs.loc[i,"x"], dfs.loc[i,"y"], marker=marker, color=c,
                s=size, alpha=alpha)

plt.show();

# %%
def rand_num(low, high, quantity):
    return np.random.choice(np.abs(np.random.normal(low, high, quantity)))
rand_num(0,1,len(df.index))
# Out:
# 1.0115378126686647

# %%
np.random.randint(1,101,len(df.index))
# Out:
# array([ 7, 30, 70, ..., 64, 58,  9])

# %%
alpha = np.abs(np.random.normal(0,1,len(dfs.index)))
alpha.max(), alpha.min(), alpha.max() - np.floor(alpha.max())
# Out:
# (3.1852691071866186, 0.00045574907660479936, 0.1852691071866186)

# %%
len(dfs.index)
# Out:
# 10000

# %%
z = np.abs(10 / np.random.normal(-1,1,len(dfs.index)))

# %%
type(z)
# Out:
# numpy.ndarray

# %%
np.random.choice(z)
# Out:
# 3.567962250265805

# %%
z.max(), z.min()
# Out:
# (63205.063718459875, 2.0682720747555923)

# %%
z[132]
# Out:
# 216.99103347182628

# %%
list(df.sample(10).index)
# Out:
# [293968,
#  387560,
#  378546,
#  713202,
#  1303952,
#  1704057,
#  506643,
#  1922569,
#  711391,
#  1958108]

# %%
import matplotlib.style as ms
ms.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
dir(plt.scatter(dfs["x"],dfs["y"]))
# Out:
# ['_A',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_checker',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_antialiaseds',
#  '_axes',
#  '_bcast_lwls',
#  '_capstyle',
#  '_check_update',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_default_contains',
#  '_edge_default',
#  '_edgecolors',
#  '_facecolors',
#  '_factor',
#  '_get_clipping_extent_bbox',
#  '_gid',
#  '_hatch',
#  '_hatch_color',
#  '_in_layout',
#  '_is_filled',
#  '_is_stroked',
#  '_joinstyle',
#  '_label',
#  '_linestyles',
#  '_linewidths',
#  '_mouseover',
#  '_offset_position',
# ...
