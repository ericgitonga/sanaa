# %%
import pandas as pd
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df = pd.read_csv("../../media/data/art/cksum.csv", error_bad_lines=False, header=None, usecols=[0,1])
df["value"] = df[1].apply(lambda x: x.split()[1]).apply(lambda x: int(x,16))
df = df.sample(len(df.index))
df.head()
# Out:
#                                                        0  \
# 77720      delton.56310 > mba01s07-in-f1.1e100.net.ht...
# 73981      delton.56010 > mba01s08-in-f14.1e100.net.h...
# 28262      bru30r3.msedge.net.https > delton.39204: F...
# 67495      delton.57876 > 104.21.13.130.https: Flags [.]
# 77069      mba01s08-in-f14.1e100.net.https > delton.5...
#
#                              1  value
# 77720   cksum 0x099b (correct)   2459
# 73981   cksum 0xdb6c (correct)  56172
# 28262   cksum 0x6022 (correct)  24610
# 67495   cksum 0xfd4c (correct)  64844
# 77069   cksum 0x622a (correct)  25130

# %%
x = df.loc[0,1].split()[1]

# %%
x.encode("utf-8")
# Out:
# b'0x021b'

# %%
int(x,16)
# Out:
# 539

# %%
int(0x021b)
# Out:
# 539

# %%
# Out:
#                                                         0  \
# 107313      delton.51575 > 185.162.184.34.52281: Flags...
# 50999       mba01s07-in-f1.1e100.net.https > delton.55...
# 79957        delton.39886 > 104.16.18.94.https: Flags [.]
# 62953         40.81.94.43.https > delton.45134: Flags [.]
# 158694      delton.35423 > cpc88922-bele11-2-0-cust238...
#
#                               1  value
# 107313   cksum 0xb9e7 (correct)  47591
# 50999    cksum 0x4de3 (correct)  19939
# 79957    cksum 0xe158 (correct)  57688
# 62953    cksum 0xe66b (correct)  58987
# 158694   cksum 0xbcd7 (correct)  48343

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163582 entries, 107313 to 10029
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       163582 non-null  object
#  1   1       163582 non-null  object
#  2   value   163582 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 5.0+ MB

# %%
df.head()
# Out:
#                                                         0  \
# 107313      delton.51575 > 185.162.184.34.52281: Flags...
# 50999       mba01s07-in-f1.1e100.net.https > delton.55...
# 79957        delton.39886 > 104.16.18.94.https: Flags [.]
# 62953         40.81.94.43.https > delton.45134: Flags [.]
# 158694      delton.35423 > cpc88922-bele11-2-0-cust238...
#
#                               1  value
# 107313   cksum 0xb9e7 (correct)  47591
# 50999    cksum 0x4de3 (correct)  19939
# 79957    cksum 0xe158 (correct)  57688
# 62953    cksum 0xe66b (correct)  58987
# 158694   cksum 0xbcd7 (correct)  48343

# %%
df.loc[350,0]
# Out:
# '    delton.33558 > 162.159.153.4.https: Flags [.]'

# %%
import numpy as np
df["x"] = np.random.rand(len(df.index)) * 100000 * np.random.rand(len(df.index))
df["y"] = np.random.rand(len(df.index)) * 100000

# %%
np.random.rand(5)
# Out:
# array([0.03132858, 0.35162784, 0.90850779, 0.57950001, 0.66163157])

# %%
import matplotlib.pyplot as plt

# %%
dfs = df.sample(len(df.index))

plt.figure(figsize=(10,5))

for i in list(dfs["value"].unique()):
    marker = np.random.choice(["x","o","<",">","^",","])

plt.xticks([])
plt.yticks([])

plt.xlim(1000,80000)
plt.ylim(1000,80000)
    
plt.scatter(dfs["x"], dfs["y"], marker=marker, c=dfs["value"], s=dfs["y"]/1e3, alpha=0.5)
plt.show();

# %%
dfs = df.sample(len(df.index))

plt.figure(figsize=(10,5))

for i in list(dfs["value"].unique()):
    marker = np.random.choice(["x","o","<",">","^",","])

plt.xticks([])
plt.yticks([])

plt.xlim(1000,80000)
plt.ylim(1000,80000)
    
plt.scatter(dfs["x"], dfs["y"], marker=marker, c=dfs["value"], s=dfs["y"]/1e3, alpha=0.5)
plt.show();
